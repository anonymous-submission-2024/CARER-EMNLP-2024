# %%
import pandas as pd

# %%
note_df = pd.read_csv('data/mimic3/raw/NOTEEVENTS.csv.gz')
# Out:
# /tmp/ipykernel_372600/2892059996.py:1: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   note_df = pd.read_csv('data/mimic3/raw/NOTEEVENTS.csv.gz')

# %%
note_df
# Out:
#           ROW_ID  SUBJECT_ID   HADM_ID   CHARTDATE            CHARTTIME  \
# 0            174       22532  167853.0  2151-08-04                  NaN
# 1            175       13702  107527.0  2118-06-14                  NaN
# 2            176       13702  167118.0  2119-05-25                  NaN
# 3            177       13702  196489.0  2124-08-18                  NaN
# 4            178       26880  135453.0  2162-03-25                  NaN
# ...          ...         ...       ...         ...                  ...
# 2083175  2070657       31097  115637.0  2132-01-21  2132-01-21 03:27:00
# 2083176  2070658       31097  115637.0  2132-01-21  2132-01-21 09:50:00
# 2083177  2070659       31097  115637.0  2132-01-21  2132-01-21 16:42:00
# 2083178  2070660       31097  115637.0  2132-01-21  2132-01-21 18:05:00
# 2083179  2070661       31097  115637.0  2132-01-21  2132-01-21 18:05:00
#
#                    STORETIME           CATEGORY DESCRIPTION     CGID  ISERROR  \
# ...

# %%
note_df['CATEGORY'].unique()
# Out:
# array(['Discharge summary', 'Echo', 'ECG', 'Nursing', 'Physician ',
#        'Rehab Services', 'Case Management ', 'Respiratory ', 'Nutrition',
#        'General', 'Social Work', 'Pharmacy', 'Consult', 'Radiology',
#        'Nursing/other'], dtype=object)

# %%
note_df[note_df['CATEGORY'] != 'Discharge summary']
# Out:
#           ROW_ID  SUBJECT_ID   HADM_ID   CHARTDATE            CHARTTIME  \
# 52108      59653       31038  174978.0  2102-06-14                  NaN
# 52109      59654       70150  156140.0  2191-05-10                  NaN
# 52110      59655       54190  188571.0  2158-02-16                  NaN
# 52111      59656        5771  185291.0  2173-09-02                  NaN
# 52112      59657       80030  100442.0  2119-06-07                  NaN
# ...          ...         ...       ...         ...                  ...
# 2083175  2070657       31097  115637.0  2132-01-21  2132-01-21 03:27:00
# 2083176  2070658       31097  115637.0  2132-01-21  2132-01-21 09:50:00
# 2083177  2070659       31097  115637.0  2132-01-21  2132-01-21 16:42:00
# 2083178  2070660       31097  115637.0  2132-01-21  2132-01-21 18:05:00
# 2083179  2070661       31097  115637.0  2132-01-21  2132-01-21 18:05:00
#
#                    STORETIME       CATEGORY DESCRIPTION     CGID  ISERROR  \
# ...

# %%
from pprint import pprint

# %%
pprint(note_df.iloc[2083176]['TEXT'])
# Out:
# ('Neonatology\n'
#  'DOL #5, CGA 36 weeks.\n'
#  '\n'
#  'CVR: Continues in RA, O2sats > 96%, RR 30-40s, overall comfortable with mild '
#  'intermittent retractions.  No spells.  Hemodynamically stable, no murmur.\n'
#  '\n'
#  'FEN: Wt 1730, no change.  BW 1860 gm. TF 120 cc/kg/day, PE20/BM20, PO/PG.  '
#  'Some breast-feeding, mostly PO.  Voiding/[** 21**].\n'
#  '\n'
#  'GI: Bili 7.7/0.3 yesterday, on phototherapy, due for bili tomorrow.\n'
#  '\n'
#  'DEV: In isolette.\n'
#  '\n'
#  'IMP: Former 35+ wk twin, mildly growth restricted, overall stable.  Mild '
#  'feeding immaturity, hyperbilirubinemia.\n'
#  '\n'
#  'PLANS:\n'
#  '- Continue monitoring resp status.\n'
#  '- Advance PO as able.\n'
#  '- Switch to E24.\n'
#  '- Continue photo, check bili in am.\n')
